# %% [markdown]
# # ROBERTa and CNN for drug review

# %% [markdown]
# ## install and import libraries

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import re

# %% [markdown]
# ## load dataset

# %%
train=pd.read_csv('/kaggle/input/medi-drugfinal-data/modified_dataset.csv')

# %%
train
# Out:
#        uniqueID Drug Name                                     Generic Name  \
# 0         94783   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 1         94670   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 2         94649   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 3         94633   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 4         95078   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# ...         ...       ...                                              ...
# 52542     51794     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52543     51802     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52544     51805     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52545     51806     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52546     51795     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
#
#                       Drug Class  \
# 0        Atypical antipsychotics
# 1        Atypical antipsychotics
# 2        Atypical antipsychotics
# 3        Atypical antipsychotics
# 4        Atypical antipsychotics
# ...                          ...
# 52542  Oxazolidinone antibiotics
# 52543  Oxazolidinone antibiotics
# 52544  Oxazolidinone antibiotics
# 52545  Oxazolidinone antibiotics
# 52546  Oxazolidinone antibiotics
#
#                                                     Uses  \
# 0      Abilify is an antipsychotic medication. It wor...
# 1      Abilify is an antipsychotic medication. It wor...
# 2      Abilify is an antipsychotic medication. It wor...
# 3      Abilify is an antipsychotic medication. It wor...
# 4      Abilify is an antipsychotic medication. It wor...
# ...                                                  ...
# 52542  Zyvox is anoxazolidinone antibioticthat fights...
# 52543  Zyvox is anoxazolidinone antibioticthat fights...
# 52544  Zyvox is anoxazolidinone antibioticthat fights...
# 52545  Zyvox is anoxazolidinone antibioticthat fights...
# 52546  Zyvox is anoxazolidinone antibioticthat fights...
#
#                                                 Warnings  \
# 0      Abilify is not approved for use in older adult...
# 1      Abilify is not approved for use in older adult...
# 2      Abilify is not approved for use in older adult...
# 3      Abilify is not approved for use in older adult...
# 4      Abilify is not approved for use in older adult...
# ...                                                  ...
# 52542  Some medicines can cause unwanted or dangerous...
# 52543  Some medicines can cause unwanted or dangerous...
# 52544  Some medicines can cause unwanted or dangerous...
# 52545  Some medicines can cause unwanted or dangerous...
# 52546  Some medicines can cause unwanted or dangerous...
#
#                                     Pre-Use Instructions  \
# 0      You should not take Abilify if you are allergi...
# 1      You should not take Abilify if you are allergi...
# 2      You should not take Abilify if you are allergi...
# 3      You should not take Abilify if you are allergi...
# 4      You should not take Abilify if you are allergi...
# ...                                                  ...
# 52542  You should not use Zyvox if you are allergic t...
# 52543  You should not use Zyvox if you are allergic t...
# 52544  You should not use Zyvox if you are allergic t...
# 52545  You should not use Zyvox if you are allergic t...
# 52546  You should not use Zyvox if you are allergic t...
#
#                                                   Dosage  \
# 0      Take Abilify exactly as prescribed by your doc...
# 1      Take Abilify exactly as prescribed by your doc...
# 2      Take Abilify exactly as prescribed by your doc...
# 3      Take Abilify exactly as prescribed by your doc...
# 4      Take Abilify exactly as prescribed by your doc...
# ...                                                  ...
# 52542  Not Available\n\nSeek emergency medical attent...
# 52543  Not Available\n\nSeek emergency medical attent...
# 52544  Not Available\n\nSeek emergency medical attent...
# 52545  Not Available\n\nSeek emergency medical attent...
# 52546  Not Available\n\nSeek emergency medical attent...
#
#                                             Side Effects  \
# 0      Get emergency medical help if you havesigns of...
# 1      Get emergency medical help if you havesigns of...
# 2      Get emergency medical help if you havesigns of...
# 3      Get emergency medical help if you havesigns of...
# 4      Get emergency medical help if you havesigns of...
# ...                                                  ...
# 52542  Get emergency medical help if you havesigns of...
# 52543  Get emergency medical help if you havesigns of...
# 52544  Get emergency medical help if you havesigns of...
# 52545  Get emergency medical help if you havesigns of...
# 52546  Get emergency medical help if you havesigns of...
#
#                                                condition  \
# 0                                             Depression
# 1                               Major Depressive Disorde
# 2                                             Depression
# 3                                        Bipolar Disorde
# 4                                        Bipolar Disorde
# ...                                                  ...
# 52542  Methicillin-Resistant Staphylococcus Aureus In...
# 52543                       Skin and Structure Infection
# 52544                       Skin and Structure Infection
# 52545                       Skin and Structure Infection
# 52546  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                                   review  rating       date  \
# 0      "For the past 20 years I have been on antidepr...      10   8-Aug-13
# 1      "5 days - from non functioning depressed to li...      10  15-Sep-15
# 2      "On 2 mg. It made me feel empty inside. Like t...       5  29-Feb-16
# 3      "Took Abilify along with Lithium.  Abilify is ...       7  15-May-16
# 4      "I am bipolar and have swung into a massive de...       9  14-Jun-09
# ...                                                  ...     ...        ...
# 52542  "I had a MRSA staph infection when I was 14. I...      10  29-Jul-12
# 52543  "My father is taking this medicine for Celluli...       5  22-Jul-09
# 52544  "I had the MRSA virus i my thigh and it was th...      10  11-Mar-08
# 52545  "7 day treatment worked well on an infection t...      10   8-Mar-08
# 52546  "I contracted MRSA in my right foot second toe...       8  21-Jun-12
#
#        usefulCount
# 0              162
# 1               23
# 2               19
# 3               10
# 4               81
# ...            ...
# 52542           29
# 52543            8
# 52544           29
# 52545           39
# 52546           28
#
# [52547 rows x 14 columns]

# %%
test=pd.read_csv('/kaggle/input/medi-drugfinal-data/modified_dataset.csv')

# %%
test
# Out:
#        uniqueID Drug Name                                     Generic Name  \
# 0         94783   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 1         94670   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 2         94649   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 3         94633   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 4         95078   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# ...         ...       ...                                              ...
# 52542     51794     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52543     51802     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52544     51805     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52545     51806     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 52546     51795     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
#
#                       Drug Class  \
# 0        Atypical antipsychotics
# 1        Atypical antipsychotics
# 2        Atypical antipsychotics
# 3        Atypical antipsychotics
# 4        Atypical antipsychotics
# ...                          ...
# 52542  Oxazolidinone antibiotics
# 52543  Oxazolidinone antibiotics
# 52544  Oxazolidinone antibiotics
# 52545  Oxazolidinone antibiotics
# 52546  Oxazolidinone antibiotics
#
#                                                     Uses  \
# 0      Abilify is an antipsychotic medication. It wor...
# 1      Abilify is an antipsychotic medication. It wor...
# 2      Abilify is an antipsychotic medication. It wor...
# 3      Abilify is an antipsychotic medication. It wor...
# 4      Abilify is an antipsychotic medication. It wor...
# ...                                                  ...
# 52542  Zyvox is anoxazolidinone antibioticthat fights...
# 52543  Zyvox is anoxazolidinone antibioticthat fights...
# 52544  Zyvox is anoxazolidinone antibioticthat fights...
# 52545  Zyvox is anoxazolidinone antibioticthat fights...
# 52546  Zyvox is anoxazolidinone antibioticthat fights...
#
#                                                 Warnings  \
# 0      Abilify is not approved for use in older adult...
# 1      Abilify is not approved for use in older adult...
# 2      Abilify is not approved for use in older adult...
# 3      Abilify is not approved for use in older adult...
# 4      Abilify is not approved for use in older adult...
# ...                                                  ...
# 52542  Some medicines can cause unwanted or dangerous...
# 52543  Some medicines can cause unwanted or dangerous...
# 52544  Some medicines can cause unwanted or dangerous...
# 52545  Some medicines can cause unwanted or dangerous...
# 52546  Some medicines can cause unwanted or dangerous...
#
#                                     Pre-Use Instructions  \
# 0      You should not take Abilify if you are allergi...
# 1      You should not take Abilify if you are allergi...
# 2      You should not take Abilify if you are allergi...
# 3      You should not take Abilify if you are allergi...
# 4      You should not take Abilify if you are allergi...
# ...                                                  ...
# 52542  You should not use Zyvox if you are allergic t...
# 52543  You should not use Zyvox if you are allergic t...
# 52544  You should not use Zyvox if you are allergic t...
# 52545  You should not use Zyvox if you are allergic t...
# 52546  You should not use Zyvox if you are allergic t...
#
#                                                   Dosage  \
# 0      Take Abilify exactly as prescribed by your doc...
# 1      Take Abilify exactly as prescribed by your doc...
# 2      Take Abilify exactly as prescribed by your doc...
# 3      Take Abilify exactly as prescribed by your doc...
# 4      Take Abilify exactly as prescribed by your doc...
# ...                                                  ...
# 52542  Not Available\n\nSeek emergency medical attent...
# 52543  Not Available\n\nSeek emergency medical attent...
# 52544  Not Available\n\nSeek emergency medical attent...
# 52545  Not Available\n\nSeek emergency medical attent...
# 52546  Not Available\n\nSeek emergency medical attent...
#
#                                             Side Effects  \
# 0      Get emergency medical help if you havesigns of...
# 1      Get emergency medical help if you havesigns of...
# 2      Get emergency medical help if you havesigns of...
# 3      Get emergency medical help if you havesigns of...
# 4      Get emergency medical help if you havesigns of...
# ...                                                  ...
# 52542  Get emergency medical help if you havesigns of...
# 52543  Get emergency medical help if you havesigns of...
# 52544  Get emergency medical help if you havesigns of...
# 52545  Get emergency medical help if you havesigns of...
# 52546  Get emergency medical help if you havesigns of...
#
#                                                condition  \
# 0                                             Depression
# 1                               Major Depressive Disorde
# 2                                             Depression
# 3                                        Bipolar Disorde
# 4                                        Bipolar Disorde
# ...                                                  ...
# 52542  Methicillin-Resistant Staphylococcus Aureus In...
# 52543                       Skin and Structure Infection
# 52544                       Skin and Structure Infection
# 52545                       Skin and Structure Infection
# 52546  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                                   review  rating       date  \
# 0      "For the past 20 years I have been on antidepr...      10   8-Aug-13
# 1      "5 days - from non functioning depressed to li...      10  15-Sep-15
# 2      "On 2 mg. It made me feel empty inside. Like t...       5  29-Feb-16
# 3      "Took Abilify along with Lithium.  Abilify is ...       7  15-May-16
# 4      "I am bipolar and have swung into a massive de...       9  14-Jun-09
# ...                                                  ...     ...        ...
# 52542  "I had a MRSA staph infection when I was 14. I...      10  29-Jul-12
# 52543  "My father is taking this medicine for Celluli...       5  22-Jul-09
# 52544  "I had the MRSA virus i my thigh and it was th...      10  11-Mar-08
# 52545  "7 day treatment worked well on an infection t...      10   8-Mar-08
# 52546  "I contracted MRSA in my right foot second toe...       8  21-Jun-12
#
#        usefulCount
# 0              162
# 1               23
# 2               19
# 3               10
# 4               81
# ...            ...
# 52542           29
# 52543            8
# 52544           29
# 52545           39
# 52546           28
#
# [52547 rows x 14 columns]

# %%
df=pd.concat([train,test],axis=0).reset_index(drop=True)

# %%
df
# Out:
#         uniqueID Drug Name                                     Generic Name  \
# 0          94783   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 1          94670   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 2          94649   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 3          94633   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 4          95078   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# ...          ...       ...                                              ...
# 105089     51794     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105090     51802     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105091     51805     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105092     51806     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105093     51795     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
#
#                        Drug Class  \
# 0         Atypical antipsychotics
# 1         Atypical antipsychotics
# 2         Atypical antipsychotics
# 3         Atypical antipsychotics
# 4         Atypical antipsychotics
# ...                           ...
# 105089  Oxazolidinone antibiotics
# 105090  Oxazolidinone antibiotics
# 105091  Oxazolidinone antibiotics
# 105092  Oxazolidinone antibiotics
# 105093  Oxazolidinone antibiotics
#
#                                                      Uses  \
# 0       Abilify is an antipsychotic medication. It wor...
# 1       Abilify is an antipsychotic medication. It wor...
# 2       Abilify is an antipsychotic medication. It wor...
# 3       Abilify is an antipsychotic medication. It wor...
# 4       Abilify is an antipsychotic medication. It wor...
# ...                                                   ...
# 105089  Zyvox is anoxazolidinone antibioticthat fights...
# 105090  Zyvox is anoxazolidinone antibioticthat fights...
# 105091  Zyvox is anoxazolidinone antibioticthat fights...
# 105092  Zyvox is anoxazolidinone antibioticthat fights...
# 105093  Zyvox is anoxazolidinone antibioticthat fights...
#
#                                                  Warnings  \
# 0       Abilify is not approved for use in older adult...
# 1       Abilify is not approved for use in older adult...
# 2       Abilify is not approved for use in older adult...
# 3       Abilify is not approved for use in older adult...
# 4       Abilify is not approved for use in older adult...
# ...                                                   ...
# 105089  Some medicines can cause unwanted or dangerous...
# 105090  Some medicines can cause unwanted or dangerous...
# 105091  Some medicines can cause unwanted or dangerous...
# 105092  Some medicines can cause unwanted or dangerous...
# 105093  Some medicines can cause unwanted or dangerous...
#
#                                      Pre-Use Instructions  \
# 0       You should not take Abilify if you are allergi...
# 1       You should not take Abilify if you are allergi...
# 2       You should not take Abilify if you are allergi...
# 3       You should not take Abilify if you are allergi...
# 4       You should not take Abilify if you are allergi...
# ...                                                   ...
# 105089  You should not use Zyvox if you are allergic t...
# 105090  You should not use Zyvox if you are allergic t...
# 105091  You should not use Zyvox if you are allergic t...
# 105092  You should not use Zyvox if you are allergic t...
# 105093  You should not use Zyvox if you are allergic t...
#
#                                                    Dosage  \
# 0       Take Abilify exactly as prescribed by your doc...
# 1       Take Abilify exactly as prescribed by your doc...
# 2       Take Abilify exactly as prescribed by your doc...
# 3       Take Abilify exactly as prescribed by your doc...
# 4       Take Abilify exactly as prescribed by your doc...
# ...                                                   ...
# 105089  Not Available\n\nSeek emergency medical attent...
# 105090  Not Available\n\nSeek emergency medical attent...
# 105091  Not Available\n\nSeek emergency medical attent...
# 105092  Not Available\n\nSeek emergency medical attent...
# 105093  Not Available\n\nSeek emergency medical attent...
#
#                                              Side Effects  \
# 0       Get emergency medical help if you havesigns of...
# 1       Get emergency medical help if you havesigns of...
# 2       Get emergency medical help if you havesigns of...
# 3       Get emergency medical help if you havesigns of...
# 4       Get emergency medical help if you havesigns of...
# ...                                                   ...
# 105089  Get emergency medical help if you havesigns of...
# 105090  Get emergency medical help if you havesigns of...
# 105091  Get emergency medical help if you havesigns of...
# 105092  Get emergency medical help if you havesigns of...
# 105093  Get emergency medical help if you havesigns of...
#
#                                                 condition  \
# 0                                              Depression
# 1                                Major Depressive Disorde
# 2                                              Depression
# 3                                         Bipolar Disorde
# 4                                         Bipolar Disorde
# ...                                                   ...
# 105089  Methicillin-Resistant Staphylococcus Aureus In...
# 105090                       Skin and Structure Infection
# 105091                       Skin and Structure Infection
# 105092                       Skin and Structure Infection
# 105093  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                                    review  rating       date  \
# 0       "For the past 20 years I have been on antidepr...      10   8-Aug-13
# 1       "5 days - from non functioning depressed to li...      10  15-Sep-15
# 2       "On 2 mg. It made me feel empty inside. Like t...       5  29-Feb-16
# 3       "Took Abilify along with Lithium.  Abilify is ...       7  15-May-16
# 4       "I am bipolar and have swung into a massive de...       9  14-Jun-09
# ...                                                   ...     ...        ...
# 105089  "I had a MRSA staph infection when I was 14. I...      10  29-Jul-12
# 105090  "My father is taking this medicine for Celluli...       5  22-Jul-09
# 105091  "I had the MRSA virus i my thigh and it was th...      10  11-Mar-08
# 105092  "7 day treatment worked well on an infection t...      10   8-Mar-08
# 105093  "I contracted MRSA in my right foot second toe...       8  21-Jun-12
#
#         usefulCount
# 0               162
# 1                23
# 2                19
# 3                10
# 4                81
# ...             ...
# 105089           29
# 105090            8
# 105091           29
# 105092           39
# 105093           28
#
# [105094 rows x 14 columns]

# %% [markdown]
# ## dataset information

# %%
train.rating.value_counts()
# Out:
# rating
# 10    16584
# 9      9500
# 8      6632
# 1      6564
# 7      3242
# 5      2472
# 6      2071
# 2      2027
# 3      1936
# 4      1519
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# uniqueID                0
# Drug Name               0
# Generic Name            0
# Drug Class              0
# Uses                    0
# Warnings                0
# Pre-Use Instructions    0
# Dosage                  0
# Side Effects            0
# condition               0
# review                  0
# rating                  0
# date                    0
# usefulCount             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105094 entries, 0 to 105093
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   uniqueID              105094 non-null  int64
#  1   Drug Name             105094 non-null  object
#  2   Generic Name          105094 non-null  object
#  3   Drug Class            105094 non-null  object
#  4   Uses                  105094 non-null  object
#  5   Warnings              105094 non-null  object
#  6   Pre-Use Instructions  105094 non-null  object
#  7   Dosage                105094 non-null  object
#  8   Side Effects          105094 non-null  object
#  9   condition             105094 non-null  object
#  10  review                105094 non-null  object
#  11  rating                105094 non-null  int64
#  12  date                  105094 non-null  object
#  13  usefulCount           105094 non-null  int64
# dtypes: int64(3), object(11)
# memory usage: 11.2+ MB

# %%
print(df['review'].dtype)
# Out:
# object

# %%
df.date.max()
# Out:
# '9-Sep-17'

# %%
df.date.min()
# Out:
# '1-Apr-08'

# %%
df['rating'].value_counts()
# Out:
# rating
# 10    33168
# 9     19000
# 8     13264
# 1     13128
# 7      6484
# 5      4944
# 6      4142
# 2      4054
# 3      3872
# 4      3038
# Name: count, dtype: int64

# %% [markdown]
# ## convert label

# %%
    # handle categorical data

df = df.replace({'rating':[1,2,3,4]},0).replace({'rating':[5,6]},1).replace({'rating':[7,8,9,10]},2)  # Create label from  rate column

df.rename(columns = {'rating':'label'}, inplace = True)

df
# Out:
#         uniqueID Drug Name                                     Generic Name  \
# 0          94783   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 1          94670   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 2          94649   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 3          94633   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 4          95078   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# ...          ...       ...                                              ...
# 105089     51794     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105090     51802     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105091     51805     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105092     51806     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105093     51795     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
#
#                        Drug Class  \
# 0         Atypical antipsychotics
# 1         Atypical antipsychotics
# 2         Atypical antipsychotics
# 3         Atypical antipsychotics
# 4         Atypical antipsychotics
# ...                           ...
# 105089  Oxazolidinone antibiotics
# 105090  Oxazolidinone antibiotics
# 105091  Oxazolidinone antibiotics
# 105092  Oxazolidinone antibiotics
# 105093  Oxazolidinone antibiotics
#
#                                                      Uses  \
# 0       Abilify is an antipsychotic medication. It wor...
# 1       Abilify is an antipsychotic medication. It wor...
# 2       Abilify is an antipsychotic medication. It wor...
# 3       Abilify is an antipsychotic medication. It wor...
# 4       Abilify is an antipsychotic medication. It wor...
# ...                                                   ...
# 105089  Zyvox is anoxazolidinone antibioticthat fights...
# 105090  Zyvox is anoxazolidinone antibioticthat fights...
# 105091  Zyvox is anoxazolidinone antibioticthat fights...
# 105092  Zyvox is anoxazolidinone antibioticthat fights...
# 105093  Zyvox is anoxazolidinone antibioticthat fights...
#
#                                                  Warnings  \
# 0       Abilify is not approved for use in older adult...
# 1       Abilify is not approved for use in older adult...
# 2       Abilify is not approved for use in older adult...
# 3       Abilify is not approved for use in older adult...
# 4       Abilify is not approved for use in older adult...
# ...                                                   ...
# 105089  Some medicines can cause unwanted or dangerous...
# 105090  Some medicines can cause unwanted or dangerous...
# 105091  Some medicines can cause unwanted or dangerous...
# 105092  Some medicines can cause unwanted or dangerous...
# 105093  Some medicines can cause unwanted or dangerous...
#
#                                      Pre-Use Instructions  \
# 0       You should not take Abilify if you are allergi...
# 1       You should not take Abilify if you are allergi...
# 2       You should not take Abilify if you are allergi...
# 3       You should not take Abilify if you are allergi...
# 4       You should not take Abilify if you are allergi...
# ...                                                   ...
# 105089  You should not use Zyvox if you are allergic t...
# 105090  You should not use Zyvox if you are allergic t...
# 105091  You should not use Zyvox if you are allergic t...
# 105092  You should not use Zyvox if you are allergic t...
# 105093  You should not use Zyvox if you are allergic t...
#
#                                                    Dosage  \
# 0       Take Abilify exactly as prescribed by your doc...
# 1       Take Abilify exactly as prescribed by your doc...
# 2       Take Abilify exactly as prescribed by your doc...
# 3       Take Abilify exactly as prescribed by your doc...
# 4       Take Abilify exactly as prescribed by your doc...
# ...                                                   ...
# 105089  Not Available\n\nSeek emergency medical attent...
# 105090  Not Available\n\nSeek emergency medical attent...
# 105091  Not Available\n\nSeek emergency medical attent...
# 105092  Not Available\n\nSeek emergency medical attent...
# 105093  Not Available\n\nSeek emergency medical attent...
#
#                                              Side Effects  \
# 0       Get emergency medical help if you havesigns of...
# 1       Get emergency medical help if you havesigns of...
# 2       Get emergency medical help if you havesigns of...
# 3       Get emergency medical help if you havesigns of...
# 4       Get emergency medical help if you havesigns of...
# ...                                                   ...
# 105089  Get emergency medical help if you havesigns of...
# 105090  Get emergency medical help if you havesigns of...
# 105091  Get emergency medical help if you havesigns of...
# 105092  Get emergency medical help if you havesigns of...
# 105093  Get emergency medical help if you havesigns of...
#
#                                                 condition  \
# 0                                              Depression
# 1                                Major Depressive Disorde
# 2                                              Depression
# 3                                         Bipolar Disorde
# 4                                         Bipolar Disorde
# ...                                                   ...
# 105089  Methicillin-Resistant Staphylococcus Aureus In...
# 105090                       Skin and Structure Infection
# 105091                       Skin and Structure Infection
# 105092                       Skin and Structure Infection
# 105093  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                                    review  label       date  \
# 0       "For the past 20 years I have been on antidepr...      2   8-Aug-13
# 1       "5 days - from non functioning depressed to li...      2  15-Sep-15
# 2       "On 2 mg. It made me feel empty inside. Like t...      1  29-Feb-16
# 3       "Took Abilify along with Lithium.  Abilify is ...      2  15-May-16
# 4       "I am bipolar and have swung into a massive de...      2  14-Jun-09
# ...                                                   ...    ...        ...
# 105089  "I had a MRSA staph infection when I was 14. I...      2  29-Jul-12
# 105090  "My father is taking this medicine for Celluli...      1  22-Jul-09
# 105091  "I had the MRSA virus i my thigh and it was th...      2  11-Mar-08
# 105092  "7 day treatment worked well on an infection t...      2   8-Mar-08
# 105093  "I contracted MRSA in my right foot second toe...      2  21-Jun-12
#
#         usefulCount
# 0               162
# 1                23
# 2                19
# 3                10
# 4                81
# ...             ...
# 105089           29
# 105090            8
# 105091           29
# 105092           39
# 105093           28
#
# [105094 rows x 14 columns]

# %%
df.label.value_counts()
# Out:
# label
# 2    71916
# 0    24092
# 1     9086
# Name: count, dtype: int64

# %% [markdown]
# ## pre-processing

# %%
import re
import torch
from transformers import pipeline, AutoTokenizer


device = 0 if torch.cuda.is_available() else -1  

def minimal_preprocess(text):
    text = text.lower()
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    # Optional: Handle negations if necessary
    negation_terms = r"\b(?:not|isn't|wasn't|aren't|weren't|don't|doesn't|didn't|haven't|hasn't|hadn't)\b \w+"
    text = re.sub(negation_terms, lambda x: x.group().replace(" ", "_"), text)
    return text

# Preprocess the reviews
df['review'] = df['review'].apply(minimal_preprocess)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import torch
from transformers import RobertaTokenizer, RobertaModel
from torch.utils.data import DataLoader, Dataset
import numpy as np

# Load RoBERTa
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaModel.from_pretrained('roberta-base')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Use mixed precision to save memory
if device.type == 'cuda':
    model.half()

# Freeze model parameters if you're only generating embeddings
for param in model.parameters():
    param.requires_grad = False

# Dataset class for handling text data
class ReviewDataset(Dataset):
    def __init__(self, reviews, tokenizer, max_length):
        self.tokenizer = tokenizer
        self.texts = reviews
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            return_token_type_ids=False,
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        return {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten()
        }

# DataLoader for batching the dataset
def create_data_loader(df, tokenizer, max_length, batch_size):
    ds = ReviewDataset(
        reviews=df['review'].to_numpy(),
        tokenizer=tokenizer,
        max_length=max_length
    )
    return DataLoader(
        ds,
        batch_size=batch_size,
        num_workers=2
    )
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Function to get embeddings from ClinicalBERT
def get_bert_embeddings(data_loader, model, device):
    model.eval()
    embeddings = []
    with torch.no_grad():
        for d in data_loader:
            input_ids = d['input_ids'].to(device)
            attention_mask = d['attention_mask'].to(device)
            outputs = model(input_ids, attention_mask=attention_mask)

            # Calculate embeddings and convert to numpy
            embeddings.append(outputs.last_hidden_state.mean(dim=1).cpu().numpy())

    # Concatenate all embeddings
    return np.concatenate(embeddings)
max_length =256  # Adjust based on your analysis
batch_size = 512   # Adjust based on your hardware capabilities
data_loader = create_data_loader(df, tokenizer, max_length, batch_size)
all_embeddings = get_bert_embeddings(data_loader, model, device)
print(all_embeddings.shape)
# Out:
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# (105094, 768)

# %% [markdown]
# ## save dataset

# %%
np.save('all_embeddings.npy', all_embeddings)

# %%
df['review'] = df['review'].astype(str)

# %%
df.dropna(subset=['review'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#         uniqueID Drug Name                                     Generic Name  \
# 0          94783   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 1          94670   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 2          94649   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 3          94633   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# 4          95078   Abilify      aripiprazole  (oral) [  AR-i-PIP-ra-zole  ]
# ...          ...       ...                                              ...
# 105089     51794     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105090     51802     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105091     51805     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105092     51806     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
# 105093     51795     Zyvox  linezolid  (oral/injection) [  lin-EZ-oh-lid  ]
#
#                        Drug Class  \
# 0         Atypical antipsychotics
# 1         Atypical antipsychotics
# 2         Atypical antipsychotics
# 3         Atypical antipsychotics
# 4         Atypical antipsychotics
# ...                           ...
# 105089  Oxazolidinone antibiotics
# 105090  Oxazolidinone antibiotics
# 105091  Oxazolidinone antibiotics
# 105092  Oxazolidinone antibiotics
# 105093  Oxazolidinone antibiotics
#
#                                                      Uses  \
# 0       Abilify is an antipsychotic medication. It wor...
# 1       Abilify is an antipsychotic medication. It wor...
# 2       Abilify is an antipsychotic medication. It wor...
# 3       Abilify is an antipsychotic medication. It wor...
# 4       Abilify is an antipsychotic medication. It wor...
# ...                                                   ...
# 105089  Zyvox is anoxazolidinone antibioticthat fights...
# 105090  Zyvox is anoxazolidinone antibioticthat fights...
# 105091  Zyvox is anoxazolidinone antibioticthat fights...
# 105092  Zyvox is anoxazolidinone antibioticthat fights...
# 105093  Zyvox is anoxazolidinone antibioticthat fights...
#
#                                                  Warnings  \
# 0       Abilify is not approved for use in older adult...
# 1       Abilify is not approved for use in older adult...
# 2       Abilify is not approved for use in older adult...
# 3       Abilify is not approved for use in older adult...
# 4       Abilify is not approved for use in older adult...
# ...                                                   ...
# 105089  Some medicines can cause unwanted or dangerous...
# 105090  Some medicines can cause unwanted or dangerous...
# 105091  Some medicines can cause unwanted or dangerous...
# 105092  Some medicines can cause unwanted or dangerous...
# 105093  Some medicines can cause unwanted or dangerous...
#
#                                      Pre-Use Instructions  \
# 0       You should not take Abilify if you are allergi...
# 1       You should not take Abilify if you are allergi...
# 2       You should not take Abilify if you are allergi...
# 3       You should not take Abilify if you are allergi...
# 4       You should not take Abilify if you are allergi...
# ...                                                   ...
# 105089  You should not use Zyvox if you are allergic t...
# 105090  You should not use Zyvox if you are allergic t...
# 105091  You should not use Zyvox if you are allergic t...
# 105092  You should not use Zyvox if you are allergic t...
# 105093  You should not use Zyvox if you are allergic t...
#
#                                                    Dosage  \
# 0       Take Abilify exactly as prescribed by your doc...
# 1       Take Abilify exactly as prescribed by your doc...
# 2       Take Abilify exactly as prescribed by your doc...
# 3       Take Abilify exactly as prescribed by your doc...
# 4       Take Abilify exactly as prescribed by your doc...
# ...                                                   ...
# 105089  Not Available\n\nSeek emergency medical attent...
# 105090  Not Available\n\nSeek emergency medical attent...
# 105091  Not Available\n\nSeek emergency medical attent...
# 105092  Not Available\n\nSeek emergency medical attent...
# 105093  Not Available\n\nSeek emergency medical attent...
#
#                                              Side Effects  \
# 0       Get emergency medical help if you havesigns of...
# 1       Get emergency medical help if you havesigns of...
# 2       Get emergency medical help if you havesigns of...
# 3       Get emergency medical help if you havesigns of...
# 4       Get emergency medical help if you havesigns of...
# ...                                                   ...
# 105089  Get emergency medical help if you havesigns of...
# 105090  Get emergency medical help if you havesigns of...
# 105091  Get emergency medical help if you havesigns of...
# 105092  Get emergency medical help if you havesigns of...
# 105093  Get emergency medical help if you havesigns of...
#
#                                                 condition  \
# 0                                              Depression
# 1                                Major Depressive Disorde
# 2                                              Depression
# 3                                         Bipolar Disorde
# 4                                         Bipolar Disorde
# ...                                                   ...
# 105089  Methicillin-Resistant Staphylococcus Aureus In...
# 105090                       Skin and Structure Infection
# 105091                       Skin and Structure Infection
# 105092                       Skin and Structure Infection
# 105093  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                                    review  label       date  \
# 0       "for the past 20 years i have been on antidepr...      2   8-Aug-13
# 1       "5 days - from non functioning depressed to li...      2  15-Sep-15
# 2       "on 2 mg. it made me feel empty inside. like t...      1  29-Feb-16
# 3       "took abilify along with lithium.  abilify is ...      2  15-May-16
# 4       "i am bipolar and have swung into a massive de...      2  14-Jun-09
# ...                                                   ...    ...        ...
# 105089  "i had a mrsa staph infection when i was 14. i...      2  29-Jul-12
# 105090  "my father is taking this medicine for celluli...      1  22-Jul-09
# 105091  "i had the mrsa virus i my thigh and it was th...      2  11-Mar-08
# 105092  "7 day treatment worked well on an infection t...      2   8-Mar-08
# 105093  "i contracted mrsa in my right foot second toe...      2  21-Jun-12
#
#         usefulCount
# 0               162
# 1                23
# 2                19
# 3                10
# 4                81
# ...             ...
# 105089           29
# 105090            8
# 105091           29
# 105092           39
# 105093           28
#
# [105094 rows x 14 columns]

# %%
df.to_csv('processdata.csv', index=False)

# %% [markdown]
# # CNN

# %%
labels=df.label

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import pickle
import seaborn as sn
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors

from keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint

from keras.layers import Dense, Input, GlobalMaxPooling1D, GlobalAveragePooling1D, Flatten, Dropout
from keras.layers import LSTM, Bidirectional, Conv1D, MaxPooling1D, Embedding, Reshape
from tensorflow.keras.layers import Concatenate
from keras.models import Model, load_model
from keras.utils import to_categorical, plot_model
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from keras.callbacks import EarlyStopping, ModelCheckpoint
import unicodedata
import re
import gc

# %%
embeddings_np = all_embeddings.numpy() if isinstance(all_embeddings, tf.Tensor) else all_embeddings
labels_np = labels.numpy() if isinstance(labels, tf.Tensor) else labels

# %%
from sklearn.model_selection import train_test_split

# Assuming you have features (X) and labels (y)
X_train, X_test, y_train, y_test = train_test_split(embeddings_np , labels,test_size=0.25, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout , BatchNormalization,Activation
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model

input_shape=(768,)
inp = Input(shape=input_shape)  # Original input shape: (768,)
inp= Reshape((-1, 1))(inp) 

conv1 = Conv1D(filters=512, kernel_size=5, padding='same')(inp)
bn1 = BatchNormalization()(conv1)
act1 = Activation('relu')(bn1)
pool1 = MaxPooling1D(pool_size=2)(act1)
drop1 = Dropout(0.3)(pool1)  # Dropout with 30% rate after the first pooling layer

# Second Convolutional Layer with Batch Normalization and Dropout
conv2 = Conv1D(filters=256, kernel_size=3, padding='same')(drop1)
bn2 = BatchNormalization()(conv2)
act2 = Activation('relu')(bn2)
pool2 = MaxPooling1D(pool_size=2)(act2)
drop2 = Dropout(0.3)(pool2)  # Dropout with 30% rate after the second pooling layer

# Flatten the output to feed into Dense layers
flatten = Flatten()(drop2)

# Fully Connected Layer with Dropout
dense = Dense(units=128)(flatten)
bn3 = BatchNormalization()(dense)
act3 = Activation('relu')(bn3)
drop3 = Dropout(0.4)(act3)

# Output Layer for 3-class classification
output = Dense(units=3, activation='softmax')(drop3)  # 3 units for 3 classes, softmax for multiclass

# Define the model
model = Model(inputs=inp, outputs=output)

# Compile the model for multiclass classification
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ keras_tensor_1CLONE             │ (None, 768, 1)         │             0 │
# │ (InputLayer)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 768, 512)       │         3,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 768, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 768, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 384, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 384, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 384, 256)       │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 384, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 384, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 192, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 192, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 49152)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,291,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,692,099 (25.53 MB)
#  Trainable params: 6,690,307 (25.52 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Convert labels to categorical if they're not already
y_train_cat = to_categorical(y_train, num_classes=3)  # Adjust 'num_classes' based on your label's unique values
y_val_cat = to_categorical(y_val, num_classes=3)

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, validation):
        super(Metrics, self).__init__()
        self.validation_data = validation

    def on_epoch_end(self, epoch, logs=None):
        # You can perform custom validation or other operations here
        val_loss, val_acc = self.model.evaluate(self.validation_data[0], self.validation_data[1], verbose=1)
        print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_acc}")

# %%
metrics = Metrics((X_val,y_val_cat))
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Define different batch sizes to experiment with
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import backend as K
batch_size = 256
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

history = model.fit(X_train, y_train_cat,
                        shuffle=True,
                        batch_size=batch_size,
                        epochs=100,
                        callbacks=[metrics,reduce_lr],  # Add ReduceLROnPlateau here
                        validation_data=(X_val, y_val_cat))
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9563 - loss: 0.1118 - val_accuracy: 0.9045 - val_loss: 0.4264 - learning_rate: 0.0010
# Epoch 96/100
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9047 - loss: 0.4234
# Validation Loss: 0.4226996898651123, Validation Accuracy: 0.9023558497428894
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9569 - loss: 0.1128 - val_accuracy: 0.9024 - val_loss: 0.4227 - learning_rate: 0.0010
# Epoch 97/100
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9059 - loss: 0.4276
# Validation Loss: 0.4273349344730377, Validation Accuracy: 0.9048357009887695
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9576 - loss: 0.1104 - val_accuracy: 0.9048 - val_loss: 0.4273 - learning_rate: 0.0010
# Epoch 98/100
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9029 - loss: 0.4180
# Validation Loss: 0.41559934616088867, Validation Accuracy: 0.901797890663147
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9567 - loss: 0.1158 - val_accuracy: 0.9018 - val_loss: 0.4156 - learning_rate: 0.0010
# Epoch 99/100
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9059 - loss: 0.4359
# Validation Loss: 0.43516623973846436, Validation Accuracy: 0.9042777419090271
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9551 - loss: 0.1131 - val_accuracy: 0.9043 - val_loss: 0.4352 - learning_rate: 0.0010
# Epoch 100/100
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9054 - loss: 0.4238
# Validation Loss: 0.42384475469589233, Validation Accuracy: 0.9052076935768127
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 48s 85ms/step - accuracy: 0.9589 - loss: 0.1080 - val_accuracy: 0.9052 - val_loss: 0.4238 - learning_rate: 0.0010

# %%
# Check the shape of y_test
print("Shape of y_test:", y_test.shape)

# If y_test is 1D, it's already in the form of class labels
if len(y_test.shape) == 1:
    ytest = y_test
# If y_test is 2D, then use argmax on axis 1 to find the class labels
elif len(y_test.shape) == 2:
    ytest = y_test.argmax(axis=1)
# Out:
# Shape of y_test: (53766,)

# %%
# result = Best_model.predict(Xtest).argmax(axis=1)
result = model.predict(X_test).argmax(axis=-1)
accuracy=accuracy_score(ytest,result)
print(classification_report(ytest, result, digits=4))
#print(confusion_matrix(y_test, result)) #y -> real; x -> predict
print(accuracy)
# Out:
# 1681/1681 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#               precision    recall  f1-score   support
#
#            0     0.8517    0.8771    0.8642     13351
#            1     0.8147    0.5829    0.6796      4910
#            2     0.9296    0.9557    0.9425     35505
#
#     accuracy                         0.9022     53766
#    macro avg     0.8653    0.8052    0.8287     53766
# weighted avg     0.8997    0.9022    0.8990     53766
#
# 0.9021500576572555

# %%
from sklearn.metrics import accuracy_score, classification_report, r2_score, mean_squared_error
import numpy as np

# Predictions
result = model.predict(X_test).argmax(axis=-1)

# Accuracy
accuracy = accuracy_score(ytest, result)
print(classification_report(ytest, result, digits=4))
print("Accuracy:", accuracy)

# Compute R-squared
r2 = r2_score(ytest, result)
print("R-squared:", r2)

# Compute RMSE
rmse = np.sqrt(mean_squared_error(ytest, result))
print("RMSE:", rmse)
# Out:
# 1681/1681 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#               precision    recall  f1-score   support
#
#            0     0.8517    0.8771    0.8642     13351
#            1     0.8147    0.5829    0.6796      4910
#            2     0.9296    0.9557    0.9425     35505
#
#     accuracy                         0.9022     53766
#    macro avg     0.8653    0.8052    0.8287     53766
# weighted avg     0.8997    0.9022    0.8990     53766
#
# Accuracy: 0.9021500576572555
# R-squared: 0.6741053297400489
# RMSE: 0.4907165554469109
